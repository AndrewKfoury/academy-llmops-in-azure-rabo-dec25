# %% [markdown]
# ## Modularizing the solution ✂️
#
# Currently, our solution does everything at once. Meaning, with a single prompt, we aim to extract all information from the given article at once.
#
# For our use case, the current solution may be sufficient.
# However, for more complex use cases, a "one prompt to rule them all" approach is generally not the best.
#
# In this notebook, we will explore how we can modularize our solution.
#
# We will split our solution in four parts/tasks:
#
# 1. Extract general information from the article (e.g. `title`, `summary`)
# 2. Classify whether the article is business-related (i.e. `is_about_business`)<br><br>
# *If business-related*: <br>
# 3. Identify which businesses or companies are involved
# 4. Extract information about each business involved (`stock_price_change`, etc.)

# %%
# For autoreloading external modules
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Redefining the LLM outputs

# %%
from typing import List, Literal
from pydantic import BaseModel, Field

# %% [markdown]
# This is what we had previously:

# %%
class BusinessSpecificInfo(BaseModel):
    business: str = Field(..., description="The business or company involved")
    stock_price_change: Literal["increase", "decrease", "none"] = Field(
        ..., description="""
        Possible stock price change as result of the article. 
        - "increase" if article speaks positively about the business
        - "decrease" if article speaks negatively about the business
        - "none" if article speaks neutrally about the business
        """
    )
    reason: str = Field(..., description="A single sentence reason for the possible stock price change")
    relevant_substring: str = Field(
        ..., description="A relevant substring from the article supporting the reason (10-20 words)"
    )

class ArticleInfo(BaseModel):
    title: str = Field(..., description="The title of the article")
    summary: str = Field(..., description="A single sentence summary of the article")
    is_about_business: bool = Field(..., description="Whether the article is about business")
    business_info: List[BusinessSpecificInfo]

# %% [markdown]
# Now let's create separate models for each of our modularized task:

# %%
class GeneralInfo(BaseModel):
    title: str = Field(..., description="The title of the article")
    summary: str = Field(..., description="A single sentence summary of the article")
    
class BusinessCategory(BaseModel):
    is_about_business: bool = Field(..., description="Whether the article is about business")
    
class BusinessesInvolved(BaseModel):
    businesses: List[str] = Field(
        ..., description="Which main businesses or companies are involved in the article"
    )

# %% [markdown]
# ## Extracting info in modularized calls

# %%
from llmops_training.news_reader.data import get_bbc_news_sample
from llmops_training.news_reader.generation import generate_object
from llmops_training.news_reader.extraction import (
    get_business_category_prompt_template, 
    get_business_specific_prompt_template, 
    get_businesses_involved_prompt_template, 
    get_general_info_prompt_template,
    format_prompt,
)

# %%
data = get_bbc_news_sample()
article = data[data["is_business"]].iloc[0].article

# %% [markdown]
# > **Exercise** 📝
# >
# > - Fill in the TODO's below to extract info from the article in modularized calls. Use the Pydantic models and the imported functions from above.

# %%
# Task 1
general_info_prompt_template = get_general_info_prompt_template()
general_info_prompt = format_prompt(general_info_prompt_template, article)
general_info = generate_object(general_info_prompt, GeneralInfo)

# Task 2
business_category_prompt_template = get_business_category_prompt_template()
business_category_prompt = format_prompt(business_category_prompt_template, article)
business_category = generate_object(business_category_prompt, BusinessCategory)

# Task 3
businesses_involved_prompt_template = get_businesses_involved_prompt_template()
businesses_involved_prompt = format_prompt(businesses_involved_prompt_template, article)
businesses_involved = generate_object(businesses_involved_prompt, BusinessesInvolved)

# Task 4
business_info = []
for business in businesses_involved.businesses:
    business_info_prompt_template = get_business_specific_prompt_template()
    prompt = format_prompt(business_info_prompt_template, business=business, article=article)
    business_info.append(generate_object(prompt, BusinessSpecificInfo))  # Task 4

output = ArticleInfo(
    title=general_info.title,
    summary=general_info.summary,
    is_about_business=business_category.is_about_business,
    business_info=business_info,
)

# %%
# %load ../solutions/modularizing-the-solution/modularize.py

# %% [markdown]
# Let's see if that worked!

# %%
output.model_dump()
# Out:
# {'title': 'Stocks slide as US central bank signals slower pace of rate cuts - BBC News',
#  'summary': 'US shares slid sharply as the Federal Reserve cut its key lending rate by a percentage point and signaled a slower pace of future cuts, amid concerns over resilient job growth and stubborn inflation, which has led to significant market declines in the US and Asia and raised questions about future monetary policy amid political uncertainty.',
#  'is_about_business': True,
#  'business_info': [{'business': 'Federal Reserve',
#    'stock_price_change': 'decrease',
#    'reason': 'The Fed signalled a slower pace of rate cuts than expected, contributing to a significant stock market decline.',
#    'relevant_substring': 'US share prices slumped after the central bank cut interest rates for the third time in a row'},
#   {'business': 'Bank of England',
#    'stock_price_change': 'none',
#    'reason': 'The article suggests stability since the Bank of England is expected to hold its benchmark rate steady amid inflation concerns.',
#    'relevant_substring': 'Bank of England is due to make its latest interest rates decision, expected to hold steady'},
#   {'business': 'Dow Jones Industrial Average',
#    'stock_price_change': 'decrease',
#    'reason': 'The index fell sharply due to central bank signals and broader market declines amid fewer expected rate cuts.',
#    'relevant_substring': 'The Dow Jones Industrial Average closed 2.58% lower, suffering its 10th session of declines in a row'},
#   {'business': 'S&P 500',
#    'stock_price_change': 'decrease',
#    'reason': 'The S&P 500 experienced a significant decline amid widespread market losses as investors reacted to signals of fewer future Fed rate cuts.',
#    'relevant_substring': 'The S&P 500 lost almost 3% and the Nasdaq Composite fell 3.6%.'},
#   {'business': 'Nasdaq Composite',
#    'stock_price_change': 'decrease',
#    'reason': 'The Nasdaq Composite fell 3.6% amid broader market declines as investors reacted to signals of slower rate cuts.',
#    'relevant_substring': 'the Nasdaq Composite fell 3.6%.'},
#   {'business': 'Fitch Ratings',
#    'stock_price_change': 'none',
#    'reason': "Fitch Ratings' head of US economic research interpreted the Fed's rate cut announcement as signaling a pause amid economic uncertainty.",
#    'relevant_substring': 'Olu Sonola, head of US economic research at Fitch Ratings, said it felt like the Fed was signalling a pause'},
#   {'business': 'Brean Capital',
#    'stock_price_change': 'none',
#    'reason': "Brean Capital's chief economic advisor expressed concern that the Fed rate cut might jeopardize progress in lowering inflation.",
#    'relevant_substring': 'chief economic advisor at Brean Capital, said he thought it would have been wiser'}]}

# %% [markdown]
# ## Integrate solution in the app
#
# We have already structured the above solution for you as functions in our package.

# %%
from llmops_training.news_reader.extraction import (
    extract_article_info,
    extract_info_from_articles,
)

# %% [markdown]
# As you see, we can call a single function from our package that does everything that we defined above:

# %%
result, _ = extract_article_info(article)
result.model_dump()

# %% [markdown]
# We also have a function that does the same thing, but on multiple articles in one go:

# %%
article1 = data[data["is_business"]].iloc[0].article
article2 = data[data["is_business"]].iloc[1].article

results, _ = extract_info_from_articles([article1, article2])
results
# Out:
# [ArticleInfo(title='Stocks slide as US central bank signals slower pace of rate cuts', summary='US share prices slid sharply after the Federal Reserve cut rates for a third consecutive time, with its economic projections signaling fewer cuts in the coming year amid persistent inflation concerns, resilient job creation and uncertain economic conditions as the transition to a new administration approaches.', is_about_business=True, business_info=[BusinessSpecificInfo(business='Federal Reserve', stock_price_change='decrease', reason='The Fed signaled a slower pace of future rate cuts, causing investor uncertainty and a drop in stock prices.', relevant_substring='Stocks in the US fell sharply as Federal Reserve chairman Jerome Powell warned the situation'), BusinessSpecificInfo(business='Fitch Ratings', stock_price_change='none', reason='Olu Sonola of Fitch Ratings noted that questions over White House policies signaled a pause to rate cuts.', relevant_substring="Fitch Ratings, said it felt like the Fed was signalling a 'pause' to cuts as questions about White House policies"), BusinessSpecificInfo(business='Brean Capital', stock_price_change='none', reason='John Ryding suggested that initiating rate cuts could risk reversing progress made in curbing inflation.', relevant_substring='Brean Capital’s chief economic advisor said the Fed should have delayed the rate cut.'), BusinessSpecificInfo(business='Bank of England', stock_price_change='none', reason='The article does not provide any direct information modifying Bank of England’s stock price, only noting its upcoming interest rate decision.', relevant_substring='a day before the Bank of England is due to make its latest interest rates decision in the UK')]),
#  ArticleInfo(title="Avanti West Coast staff to strike on New Year's Eve", summary="Avanti West Coast train managers, represented by the RMT union, will go on strike on New Year's Eve, January 2, and every Sunday from January 12 to May 25 over disputes regarding rest day working conditions and shift allocations, following the rejection of a revised offer that included higher payments and organized shifts.", is_about_business=True, business_info=[BusinessSpecificInfo(business='Avanti West Coast', stock_price_change='decrease', reason="The company's operations face significant disruption due to strike action over a rejected revised offer.", relevant_substring='This strike action will cause significant disruption to our customers making journeys on the West Coast Main Line over an extended period.')])]

# %% [markdown]
# > **Exercise** 📝
# >
# > - Import the function `extract_info_from_articles` in the `components.py` file and use it to extract information from the articles.
# > - Run the app and see if it works!
# >   ```bash
# >   uv run streamlit run src/llmops_training/news_reader/app/app.py
# >   ```
# >
# > 💡 Hint:
# >
# > - Replace the `mock_extract_info_from_articles` function.

# %% [markdown]
# ---
